# %%
import pandas as pd

# %%
citizens = pd.read_csv('obyvately_1_UTF.csv',delimiter = ';',header=1)
citizens_obec = citizens.drop(columns = ['KRAJ_ID','KRAJ','OKRES_ID','OKRES','OBEC_ID','OBEC','ZSJ_ID'])
#citizens_obec.columns
#citizens_obec.shape
#citizens_obec["maďarský"] >100
#citizens_obec[['maďarský','nemecký']]
citizens_obec.insert(0, "rus_total", 0)
citizens_obec
# Out:
#      rus_total                            ZSJ slovenský  maďarský  rómsky  \
# 0            0                    Hradný svah       175       5.0     NaN
# 1            0                         Lýceum     1 559      45.0     NaN
# 2            0                   Pamätník SNP       195      13.0     NaN
# 3            0  Bratislava - historické jadro     1 078      31.0     NaN
# 4            0                         Reduta     1 379      53.0     4.0
# ..         ...                            ...       ...       ...     ...
# 208          0                  Lúky - východ     6 871     101.0     3.0
# 209          0               Tupolevova ulica     3 760      55.0     NaN
# 210          0                Lenardova ulica     7 855     133.0     4.0
# 211          0         Bosákova ulica - sever     1 718      33.0     NaN
# 212          0                        Rusovce     2 317     189.0     NaN
#
#      rusínsky  ukrajinský  český  nemecký  poľský  chorvátsky  jidiš  \
# ...
