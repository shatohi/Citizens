# %%
import pandas as pd

# %%
citizens = pd.read_csv('obyvately_1_UTF.csv',delimiter = ';',header=1)
citizens
# Out:
#      KRAJ_ID               KRAJ  OKRES_ID         OKRES  OBEC_ID  \
# 0          1  Bratislavský kraj       101  Bratislava I  528 595
# 1          1  Bratislavský kraj       101  Bratislava I  528 595
# 2          1  Bratislavský kraj       101  Bratislava I  528 595
# 3          1  Bratislavský kraj       101  Bratislava I  528 595
# 4          1  Bratislavský kraj       101  Bratislava I  528 595
# ..       ...                ...       ...           ...      ...
# 208        1  Bratislavský kraj       105  Bratislava V  529 460
# 209        1  Bratislavský kraj       105  Bratislava V  529 460
# 210        1  Bratislavský kraj       105  Bratislava V  529 460
# 211        1  Bratislavský kraj       105  Bratislava V  529 460
# 212        1  Bratislavský kraj       105  Bratislava V  529 494
#
#                          OBEC     ZSJ_ID                            ZSJ  \
# 0    Bratislava - Staré Mesto  2 040 640                    Hradný svah
# ...
